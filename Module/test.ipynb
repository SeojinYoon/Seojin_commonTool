# %%
print(1)
# Out:
# 1

# %%
import numpy as np
from sj_opensim import run_python_onDocker
import sys
sys.path.append("/home/seojin/DeepProprioception/Biomechanics/OpenSim/MakeData")

from utils import extract_markerSet, extract_coordinateSet

# %%
container_ID = "a8f265a7dadb"
osim_model_path = "/mnt/sdb2/DeepProprioception/Projects/DP01_mri/Opensim/Model/scaled_model.osim"
# Out:
# ['Shoulder', 'Elbow', 'Wrist', 'EndEffector']

# %%
a = [[[ 0.04532566, -0.01517913,  0.06112773],
        [ 0.02315308,  0.12360225,  0.30545834],
        [-0.09255606,  0.21983849,  0.49526551],
        [-0.19865725,  0.1534649 ,  0.57099335]]]

# %%
a = np.array(a)

# %%
a
# Out:
# array([[[ 0.04532566, -0.01517913,  0.06112773],
#         [ 0.02315308,  0.12360225,  0.30545834],
#         [-0.09255606,  0.21983849,  0.49526551],
#         [-0.19865725,  0.1534649 ,  0.57099335]]])

# %%
if curr_coord.isConstrained(state) and not curr_coord.getLocked(state):

# %%
extract_markerSet(osim_model_path)

# %%
extract_coordinateSet(osim_model_path)
# Out:
# ['r_x',
#  'r_y',
#  'r_z',
#  't_x',
#  't_y',
#  't_z',
#  'sternoclavicular_r2',
#  'sternoclavicular_r3',
#  'unrotscap_r3',
#  'unrotscap_r2',
#  'acromioclavicular_r2',
#  'acromioclavicular_r3',
#  'acromioclavicular_r1',
#  'unrothum_r1',
#  'unrothum_r3',
#  'unrothum_r2',
#  'elv_angle',
#  'shoulder_elv',
#  'shoulder1_r2',
#  'shoulder_rot',
#  'elbow_flexion',
#  'pro_sup',
#  'deviation',
#  'flexion',
#  'wrist_hand_r1',
#  'wrist_hand_r3']

# %%
for curr_coord in coordSet:    
    curr_coord_name = curr_coord.getName()
